# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/statistical_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
population = np.array([10,20,30,40,50,60,70])
n = len(population)
print("population size(n):",n)
mu = np.sum(population)/n
print("population mean:",mu)
sigma2 = np.sum((population - mu)**2)/n
print("population variance:",sigma2)
sigma = math.sqrt(sigma2)
print("population standard deviation:",sigma)
sample = np.array([20,30,40,50])
n = len(sample)
print("\nsample size(n):",n)
X_bar = np.sum(sample)/n
print("sample mean:",X_bar)
s2 = np.sum((sample - X_bar)**2)/(n-1)
print("sample variance:",s2)
s = math.sqrt(s2)
print("sample standard deviation:",s)
# Out:
# population size(n): 7
# population mean: 40.0
# population variance: 400.0
# population standard deviation: 20.0
#
# sample size(n): 4
# sample mean: 35.0
# sample variance: 166.66666666666666
# sample standard deviation: 12.909944487358056
