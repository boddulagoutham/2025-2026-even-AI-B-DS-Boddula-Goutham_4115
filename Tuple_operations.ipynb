# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/Tuple_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TUPLE OPERATIONS

# Creating tuples
t = (10, 20, 30, 40, 20)
print("Original tuple:", t)
print("First element:", t[0])
print("Last element:", t[-1])
print("Sliced tuple:", t[1:4])
print("Length of tuple:", len(t))
print("Is 30 in tuple?", 30 in t)
print("Count of 20:", t.count(20))
print("Index of 40:", t.index(40))
print("Tuple elements:")
for item in t:
    print(item)
t2 = (50, 60)
t3 = t + t2
print("After concatenation:", t3)
t4 = t * 2
print("After repetition:", t4)
nested = (1, (2, 3), (4, 5))
print("Nested tuple element:", nested[1][0])
a, b, c, d, e = t
print("Unpacked values:", a, b, c, d, e)
lst = list(t)
lst.append(100)
t_new = tuple(lst)
print("Modified tuple (via list):", t_new)
# Out:
# Original tuple: (10, 20, 30, 40, 20)
# First element: 10
# Last element: 20
# Sliced tuple: (20, 30, 40)
# Length of tuple: 5
# Is 30 in tuple? True
# Count of 20: 2
# Index of 40: 3
# Tuple elements:
# 10
# 20
# 30
# 40
# 20
# After concatenation: (10, 20, 30, 40, 20, 50, 60)
# After repetition: (10, 20, 30, 40, 20, 10, 20, 30, 40, 20)
# Nested tuple element: 2
# Unpacked values: 10 20 30 40 20
# Modified tuple (via list): (10, 20, 30, 40, 20, 100)
