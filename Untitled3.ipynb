# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear Search
n=int(input("Enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}:")))
key=int(input("\nEnter key element to be found:"))
found=False
for i in range(n):
  if arr[i]==key:
    print(f"Element found at position {i+1}")
    found=True
if found==False:
  print("Element not found")
# Out:
# Enter the number of elements:5
# Enter element 1:3
# Enter element 2:4
# Enter element 3:5
# Enter element 4:2
# Enter element 5:5
#
# Enter key element to be found:3
# Element found at position 1
