# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/Dictionary_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = {
    "name": "B.Goutham",
    "age": 19,
    "course": "BTech"
}

print("Original dictionary:", d)

print("Name:", d["name"])
print("Age:", d.get("age"))

d["college"] = "XYZ University"
print("After adding:", d)

d["age"] = 21
print("After updating:", d)

d.pop("course")
print("After pop:", d)

removed_item = d.popitem()
print("After popitem:", d)
print("Removed item:", removed_item)

print("Keys:", d.keys())
print("Values:", d.values())
print("Items:", d.items())

print("Is 'name' a key?", "name" in d)

print("Length of dictionary:", len(d))

print("Looping through keys:")
for key in d:
    print(key, ":", d[key])

print("Looping through key-value pairs:")
for k, v in d.items():
    print(k, "->", v)

d_copy = d.copy()
print("Copied dictionary:", d_copy)

d.update({"city": "Hyderabad", "age": 22})
print("After update():", d)

student = {
    "id": 1,
    "info": {
        "name": "Amit",
        "marks": 90
    }
}

print("Nested dictionary value:", student["info"]["marks"])

d.clear()
print("After clear:", d)
# Out:
# Original dictionary: {'name': 'B.Goutham', 'age': 19, 'course': 'BTech'}
# Name: B.Goutham
# Age: 19
# After adding: {'name': 'B.Goutham', 'age': 19, 'course': 'BTech', 'college': 'XYZ University'}
# After updating: {'name': 'B.Goutham', 'age': 21, 'course': 'BTech', 'college': 'XYZ University'}
# After pop: {'name': 'B.Goutham', 'age': 21, 'college': 'XYZ University'}
# After popitem: {'name': 'B.Goutham', 'age': 21}
# Removed item: ('college', 'XYZ University')
# Keys: dict_keys(['name', 'age'])
# Values: dict_values(['B.Goutham', 21])
# Items: dict_items([('name', 'B.Goutham'), ('age', 21)])
# Is 'name' a key? True
# Length of dictionary: 2
# Looping through keys:
# name : B.Goutham
# age : 21
# Looping through key-value pairs:
# name -> B.Goutham
# age -> 21
# Copied dictionary: {'name': 'B.Goutham', 'age': 21}
# After update(): {'name': 'B.Goutham', 'age': 22, 'city': 'Hyderabad'}
# Nested dictionary value: 90
# After clear: {}
