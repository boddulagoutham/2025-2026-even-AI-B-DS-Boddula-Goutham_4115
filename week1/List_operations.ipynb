# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/List_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LIST OPERATIONS

# Creating a list
lst = [10, 20, 30, 40]
print("Initial list:", lst)

print("First element:", lst[0])
print("Last element:", lst[-1])
lst.append(50)
print("After append:", lst)

lst.insert(2, 25)
print("After insert:", lst)

lst.extend([60, 70])
print("After extend:", lst)
lst.remove(25)
print("After remove:", lst)
lst.pop()
print("After pop:", lst)
lst.pop(1)
print("After pop at index 1:", lst)
lst[0] = 100
print("After updating:", lst)
print("Index of 30:", lst.index(30))
print("Count of 20:", lst.count(20))
lst.sort()
print("After sort:", lst)
lst.sort(reverse=True)
print("After reverse sort:", lst)
lst.reverse()
print("After reverse:", lst)
new_lst = lst.copy()
print("Copied list:", new_lst)
print("Length of list:", len(lst))
print("Is 40 in list?", 40 in lst)
print("Elements in list:")
for item in lst:
    print(item)
squares = [x*x for x in lst]
print("Squares of elements:", squares)
lst.clear()
print("After clear:", lst)
# Out:
# Initial list: [10, 20, 30, 40]
# First element: 10
# Last element: 40
# After append: [10, 20, 30, 40, 50]
# After insert: [10, 20, 25, 30, 40, 50]
# After extend: [10, 20, 25, 30, 40, 50, 60, 70]
# After remove: [10, 20, 30, 40, 50, 60, 70]
# After pop: [10, 20, 30, 40, 50, 60]
# After pop at index 1: [10, 30, 40, 50, 60]
# After updating: [100, 30, 40, 50, 60]
# Index of 30: 1
# Count of 20: 0
# After sort: [30, 40, 50, 60, 100]
# After reverse sort: [100, 60, 50, 40, 30]
# After reverse: [30, 40, 50, 60, 100]
# Copied list: [30, 40, 50, 60, 100]
# Length of list: 5
# Is 40 in list? True
# Elements in list:
# 30
# 40
# 50
# 60
# 100
# Squares of elements: [900, 1600, 2500, 3600, 10000]
# After clear: []
