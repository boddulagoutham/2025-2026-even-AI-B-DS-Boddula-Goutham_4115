# %% [markdown]
# <a href="https://colab.research.google.com/github/boddulagoutham/2025-2026-even-AI-B-DS-Boddula-Goutham_4115/blob/main/BUbble_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Bubble Sort
n=int(input("Enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}:")))
print(f"Original Array:{arr}")
for i in range(n-1):
  for j in range(n-i-1):
    if arr[j ]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("\nSorted Array:\n")
print(arr)
# Out:
# Enter the number of elements:2
# Enter element 1:3
# Enter element 2:2
# Original Array:[3, 2]
#
# Sorted Array:
#
# [2, 3]
